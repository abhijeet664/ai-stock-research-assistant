# %%
# !pip install yfinance
import yfinance as yf
import matplotlib.pyplot as plt

ticker = yf.Ticker("AAPL")
data = ticker.history(period="1y")
data['Close'].plot(title="Apple 1-Year Closing Price")
plt.show()
